# %% [markdown]
# # 1. BigQuery

# %%
import google.auth
from google.cloud import bigquery
from google.cloud import bigquery_storage_v1beta1

# %% [markdown]
# ## 1.1. BigQuery 테이블 로드

# %%
# %load_ext google.cloud.bigquery

# %% [markdown]
# ### 1.1.1. 조회만 하기

# %% [markdown]
# - 본인이 생성했던 데이터베이스(bigquery_test_db)로부터 테이블(kc_house_data) 조회하기

# %%
# %%bigquery
# SELECT *
# FROM `bigquery_test_db.kc_house_data`
# LIMIT 5
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  3980300371  20140926T000000  142000.0         0        0.0          290
# 1  9543000205  20150413T000000  139950.0         0        0.0          844
# 2  5702500050  20141104T000000  280000.0         1        0.0          600
# 3  3374500520  20150429T000000  355000.0         0        0.0         2460
# 4  3421079032  20150217T000000   75000.0         1        0.0          670
#
#    sqft_lot  floors  waterfront  view     ...      grade  sqft_above  \
# 0     20875     1.0           0     0     ...          1         290
# 1      4269     1.0           0     0     ...          7         844
# 2     24501     1.0           0     0     ...          3         600
# 3      8049     2.0           0     0     ...          8        2460
# 4     43377     1.0           0     0     ...          3         670
#
#    sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# 0              0      1963             0    98024  47.5308 -121.888
# 1              0      1913             0    98001  47.2781 -122.250
# 2              0      1950             0    98045  47.5316 -121.749
# 3              0      1990             0    98031  47.4095 -122.168
# 4              0      1966             0    98022  47.2638 -121.906
#
#    sqft_living15  sqft_lot15
# 0           1620       22850
# 1           1380        9600
# 2            990       22549
# 3           2520        8050
# 4           1160       42882
#
# [5 rows x 21 columns]

# %% [markdown]
# ### 1.1.2. 쿼리 결과 저장

# %% [markdown]
# - 본인이 생성했던 데이터베이스(bigquery_test_db)로부터 테이블(kc_house_data) 조회하기
# - 쿼리의 결과를 변수로 저장 => %%bigquery [변수명]

# %%
# %%bigquery tmp
# SELECT *
# FROM `bigquery_test_db.kc_house_data`

# %%
tmp.shape
# Out:
# (21613, 21)

# %%
tmp.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  3980300371  20140926T000000  142000.0         0        0.0          290
# 1  9543000205  20150413T000000  139950.0         0        0.0          844
# 2  5702500050  20141104T000000  280000.0         1        0.0          600
# 3  3374500520  20150429T000000  355000.0         0        0.0         2460
# 4  3421079032  20150217T000000   75000.0         1        0.0          670
#
#    sqft_lot  floors  waterfront  view     ...      grade  sqft_above  \
# 0     20875     1.0           0     0     ...          1         290
# 1      4269     1.0           0     0     ...          7         844
# 2     24501     1.0           0     0     ...          3         600
# 3      8049     2.0           0     0     ...          8        2460
# 4     43377     1.0           0     0     ...          3         670
#
#    sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# 0              0      1963             0    98024  47.5308 -121.888
# 1              0      1913             0    98001  47.2781 -122.250
# 2              0      1950             0    98045  47.5316 -121.749
# 3              0      1990             0    98031  47.4095 -122.168
# 4              0      1966             0    98022  47.2638 -121.906
#
#    sqft_living15  sqft_lot15
# 0           1620       22850
# 1           1380        9600
# 2            990       22549
# 3           2520        8050
# 4           1160       42882
#
# [5 rows x 21 columns]

# %% [markdown]
# ## 1.2. Pandas Data Frame으로 불러오기

# %% [markdown]
# - client.query(`'sql문'`).to_dataframe()

# %%
client = bigquery.Client()

# %%
sql = """
SELECT *
FROM `bigquery_test_db.kc_house_data`
"""
df = client.query(sql).to_dataframe()
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  3980300371  20140926T000000  142000.0         0        0.0          290
# 1  9543000205  20150413T000000  139950.0         0        0.0          844
# 2  5702500050  20141104T000000  280000.0         1        0.0          600
# 3  3374500520  20150429T000000  355000.0         0        0.0         2460
# 4  3421079032  20150217T000000   75000.0         1        0.0          670
#
#    sqft_lot  floors  waterfront  view     ...      grade  sqft_above  \
# 0     20875     1.0           0     0     ...          1         290
# 1      4269     1.0           0     0     ...          7         844
# 2     24501     1.0           0     0     ...          3         600
# 3      8049     2.0           0     0     ...          8        2460
# 4     43377     1.0           0     0     ...          3         670
#
#    sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# 0              0      1963             0    98024  47.5308 -121.888
# 1              0      1913             0    98001  47.2781 -122.250
# 2              0      1950             0    98045  47.5316 -121.749
# 3              0      1990             0    98031  47.4095 -122.168
# 4              0      1966             0    98022  47.2638 -121.906
#
#    sqft_living15  sqft_lot15
# 0           1620       22850
# 1           1380        9600
# 2            990       22549
# 3           2520        8050
# 4           1160       42882
#
# [5 rows x 21 columns]

# %%
df.shape
# Out:
# (21613, 21)

# %% [markdown]
# # 2. SQL 예제

# %% [markdown]
# ## 2.1. CREATE, INSERT, DELETE, DROP

# %% [markdown]
# ### 1) CREATE - 테이블 생성

# %%
# %%bigquery
# CREATE TABLE `bigquery_test_db.instructor`(
#     `student_ID` STRING,
#     `name` STRING,
#     `age` NUMERIC,
#     `dept_name` STRING
# );
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ### 2) INSERT - 테이블에 행 추가

# %% [markdown]
# - 행 하나만 넣기

# %%
# %%bigquery
# INSERT into `bigquery_test_db.instructor` values ('1', 'mj', 23, 'Statistics');
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
# %%bigquery
# SELECT * FROM `bigquery_test_db.instructor`;
# Out:
#   student_ID name age   dept_name
# 0          1   mj  23  Statistics

# %% [markdown]
# - 행 여러개 넣기

# %%
# %%bigquery
# INSERT into `bigquery_test_db.instructor` values ('2', 'jh', 26, 'Statistics');
# INSERT into `bigquery_test_db.instructor` values ('3', 'hg', 22, 'Statistics');
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
# %%bigquery
# SELECT * FROM `bigquery_test_db.instructor`;
# Out:
#   student_ID name age   dept_name
# 0          1   mj  23  Statistics
# 1          3   hg  22  Statistics
# 2          2   jh  26  Statistics

# %% [markdown]
# ### 3) DELETE - 테이블에서 행 제거
# - 만약 DELETE문에 WHERE절을 사용하지 않을 경우 테이블에 있는 모든 행이 삭제되므로 주의
# - 특정 행을 지우고자 한다면 where 쓸 것 (BigQuery에서는 where 안쓰면 에러남)

# %% [markdown]
# student_ID가 '3'인 행 제거

# %%
# %%bigquery
# DELETE FROM `bigquery_test_db.instructor`
# WHERE student_ID = '3';
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
# %%bigquery
# SELECT * FROM `bigquery_test_db.instructor`;
# Out:
#   student_ID name age   dept_name
# 0          2   jh  26  Statistics
# 1          1   mj  23  Statistics

# %% [markdown]
# ### 4) DROP - 테이블 삭제

# %%
# %%bigquery
# DROP TABLE `bigquery_test_db.instructor`
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ## 2.2. SELECT

# %% [markdown]
# - 데이터를 처리하기 위해 가장 많이 쓰는 명령어
# - 기본적으로 `SELECT [컬럼] FROM [테이블명]`의 구조를 가짐
# - BigQuery에서는 FROM 뒤에 오는 테이블명은 반드시 `데이터세트명.테이블명`으로 작성해야함

# %% [markdown]
# ### 1) 가장 기본적인 쿼리 구조

# %% [raw]
# SELECT [컬럼명]
# FROM [데이터세트명.테이블명]

# %% [markdown]
# - [bigquery_test_db.employees]에서 [*모든 컬럼]을 행 3개까지만 뽑아라
# - __(LIMIT은 마치 pandas의 head()같은 기능으로 전처리하거나 데이터 전체를 가져올 땐 잘 사용하지 않지만 실습에서 조금씩만 조회하기 위해 사용)__

# %%
# %%bigquery
# SELECT *
# FROM bigquery_test_db.employees
# LIMIT 3
# Out:
#    emp_no  birth_date first_name last_name gender   hire_date
# 0   11846  1954-04-24        Fai     Perly      F  1993-11-21
# 1   12018  1956-12-23        Fai    Morton      F  1990-07-23
# 2   12095  1953-05-24        Fai    Smeets      F  1990-04-04

# %% [markdown]
# - 컬럼명을 본인이 원하는 대로 바꿔서 불러오고 싶다면 `as`사용

# %%
# %%bigquery
# SELECT emp_no as id
# FROM bigquery_test_db.employees
# LIMIT 3
# Out:
#       id
# 0  11846
# 1  12018
# 2  12095

# %% [markdown]
# ### 2) WHERE

# %% [markdown]
# - [bigquery_test_db.employees]에서 [gender]가 F인 행들의 [*모든 컬럼]을 뽑아라

# %%
# %%bigquery
# SELECT *
# FROM bigquery_test_db.employees
# WHERE gender = 'F'
# LIMIT 3
# Out:
#    emp_no  birth_date first_name last_name gender   hire_date
# 0   11846  1954-04-24        Fai     Perly      F  1993-11-21
# 1   12018  1956-12-23        Fai    Morton      F  1990-07-23
# 2   12095  1953-05-24        Fai    Smeets      F  1990-04-04

# %% [markdown]
# #### (1) and (or)

# %% [markdown]
# [bigquery_test_db.employees]에서 [gender]가 F이고 [emp_no]이 11846인 행들의 [*모든 컬럼]을 뽑아라

# %%
# %%bigquery
# SELECT *
# FROM bigquery_test_db.employees
# WHERE gender = 'F' and emp_no = 11846
# Out:
#    emp_no  birth_date first_name last_name gender   hire_date
# 0   11846  1954-04-24        Fai     Perly      F  1993-11-21

# %% [markdown]
# #### (2) between

# %% [markdown]
# [bigquery_test_db.employees]에서 [hire_date]가 '1990-01-01'과 '1990-06-30'사이인 행들의 [*모든 컬럼]을 뽑아라

# %%
# %%bigquery
# SELECT *
# FROM bigquery_test_db.employees
# WHERE hire_date between '1990-01-01' and '1990-06-30'
# LIMIT 5;
# Out:
#    emp_no  birth_date first_name last_name gender   hire_date
# 0   12095  1953-05-24        Fai    Smeets      F  1990-04-04
# 1   49961  1962-01-11        Fai  Comellas      F  1990-05-27
# 2   93249  1960-02-29        Fai    Radwan      F  1990-02-21
# 3  219745  1956-08-04        Fai     Merel      F  1990-03-22
# 4  236215  1959-06-19        Fai    Herber      F  1990-04-19

# %% [markdown]
# ### 3) DISTINCT

# %% [markdown]
# - SQL은 쿼리를 실행할 때 중복을 허용한다
# - 유니크한 값을 뽑기 위해서 distinct를 쓴다

# %%
# %%bigquery
# SELECT DISTINCT gender
# FROM bigquery_test_db.employees;
# Out:
#   gender
# 0      F
# 1      M

# %% [markdown]
# ### 4) String Operation

# %% [markdown]
# - [last_name] 에 'mee'가 들어가는 행 찾기

# %%
# %%bigquery
# SELECT *
# FROM bigquery_test_db.employees
# WHERE last_name like '%mee%'
# LIMIT 5;
# Out:
#    emp_no  birth_date first_name last_name gender   hire_date
# 0   12095  1953-05-24        Fai    Smeets      F  1990-04-04
# 1   73625  1953-01-27        Fan    Smeets      F  1987-04-19
# 2   67916  1957-06-12        Goa    Smeets      F  1986-05-19
# 3  102364  1956-06-10       Adil    Smeets      F  1985-11-30
# 4   56092  1957-09-21       Adin    Smeets      F  1988-10-10

# %% [markdown]
# ### 5) ORDER BY

# %% [markdown]
# - birth_date 먼저 정렬하고 그다음 hire_date 순으로 정렬
# - default는 오름차순

# %%
# %%bigquery
# SELECT *
# FROM bigquery_test_db.employees
# ORDER BY birth_date, hire_date
# LIMIT 5;
# Out:
#    emp_no  birth_date first_name     last_name gender   hire_date
# 0   65308  1952-02-01      Jouni     Pocchiola      M  1985-03-10
# 1   87461  1952-02-01       Moni  Decaestecker      M  1986-10-06
# 2  237571  1952-02-01    Ronghao        Schaad      M  1988-07-10
# 3  207658  1952-02-01   Kiyokazu      Whitcomb      M  1988-07-26
# 4  406121  1952-02-01      Supot       Remmele      M  1989-01-27

# %% [markdown]
# - 내림차순으로 정렬하고 싶은 컬럼 옆에 DESC 써주기
# - birth_date는 오름차순으로, hire_date는 내림차순으로 정렬된 것 확인할 수 있음

# %%
# %%bigquery
# SELECT *
# FROM bigquery_test_db.employees
# ORDER BY birth_date, hire_date DESC
# LIMIT 5;
# Out:
#    emp_no  birth_date first_name     last_name gender   hire_date
# 0   91374  1952-02-01    Eishiro       Kuzuoka      M  1992-02-12
# 1  406121  1952-02-01      Supot       Remmele      M  1989-01-27
# 2  207658  1952-02-01   Kiyokazu      Whitcomb      M  1988-07-26
# 3  237571  1952-02-01    Ronghao        Schaad      M  1988-07-10
# 4   87461  1952-02-01       Moni  Decaestecker      M  1986-10-06

# %% [markdown]
# ### 6) 집계함수

# %% [markdown]
# #### 1) Count
# - SQL은 카운트할 때 중복을 허용한다
# - 유니크한 값을 카운트하기 위해서 distinct를 쓴다

# %%
# %%bigquery
# SELECT COUNT(gender)
# FROM bigquery_test_db.employees;
# Out:
#       f0_
# 0  300024

# %% [markdown]
# - 만약 count 결과의 열 이름을 지정하고 싶다면 `as` 사용

# %%
# %%bigquery
# SELECT COUNT(gender) as cnt
# FROM bigquery_test_db.employees;
# Out:
#       cnt
# 0  300024

# %% [markdown]
# - 유니크한 값을 카운트하기 위해서 distinct를 쓴다

# %%
# %%bigquery
# SELECT COUNT(DISTINCT gender) as cnt
# FROM bigquery_test_db.employees;
# Out:
#    cnt
# 0    2

# %% [markdown]
# #### 2) avg, min, max, sum

# %% [markdown]
# [bigquery_test_db.salaries]에서 모든 행에 대해 [salary] 컬럼의 평균 구하기

# %%
# %%bigquery
# SELECT avg(salary) as avg_salary
# FROM bigquery_test_db.salaries;
# Out:
#      avg_salary
# 0  52970.732451

# %% [markdown]
# => min, max, sum도 마찬가지로 쓰면 됨

# %% [markdown]
# ### 7) Join

# %% [markdown]
# - left, right, inner, outer 등 여러가지 종류가 있다
# - default는 inner join
# - 서로 연결되는 key가 있을 경우 결합 가능
# - join 할 때 잘못붙이면 데이터가 뻥튀기 되는 경우 있으니 주의할 것
# ( 주의사항 참고 : https://gywn.net/2012/05/mysql-bad-sql-type/ )
# - 아래의 구문을 보고 본인의 데이터에 맞게 변형해서 사용할 것

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### 실습에서는 left join만 사용해보겠다

# %% [markdown]
# - [employees]테이블에 [salaries]테이블의 정보를 'emp_no'을 기준으로 결합

# %%
# %%bigquery
# SELECT emp.*, sal.salary
# FROM `bigquery_test_db.employees` as emp
# LEFT JOIN `bigquery_test_db.salaries` as sal
#     ON emp.emp_no = sal.emp_no;
# Out:
#         emp_no  birth_date      first_name    last_name gender   hire_date  \
# 0        11846  1954-04-24             Fai        Perly      F  1993-11-21
# 1        12018  1956-12-23             Fai       Morton      F  1990-07-23
# 2        12095  1953-05-24             Fai       Smeets      F  1990-04-04
# 3        13561  1962-04-30             Fai      Thebaut      F  1985-07-05
# 4        18036  1958-11-23             Fai    Kowalchuk      F  1985-05-15
# 5        20438  1955-03-17             Fai        Erman      F  1993-08-08
# 6        25484  1962-12-23             Fai    Gruenwald      F  1991-06-11
# 7        28799  1960-12-18             Fai      Avouris      F  1988-01-14
# 8        30469  1963-02-26             Fai         Baek      F  1987-06-17
# 9        36043  1952-12-12             Fai       Rubsam      F  1987-06-29
# 10       36137  1955-03-03             Fai       Famili      F  1986-10-21
# 11       40976  1961-08-26             Fai    Peternell      F  1988-12-24
# 12       49690  1962-10-22             Fai       Cooman      F  1989-10-31
# 13       49961  1962-01-11             Fai     Comellas      F  1990-05-27
# 14       50836  1959-06-14             Fai      Fargier      F  1987-02-08
# 15       52092  1954-02-21             Fai        Ozeri      F  1985-08-17
# 16       55868  1964-05-17             Fai       Hashii      F  1985-08-02
# 17       62996  1962-01-05             Fai    Godskesen      F  1989-11-28
# 18       72154  1961-06-21             Fai       Lipner      F  1985-11-04
# 19       72193  1953-10-29             Fai         Badr      F  1986-09-26
# 20       74559  1953-01-06             Fai    Kornatzky      F  1991-03-19
# 21       74591  1959-07-24             Fai     Zallocco      F  1986-10-24
# 22       80220  1963-01-08             Fai       Karner      F  1994-04-19
# 23       81789  1957-01-06             Fai      Domenig      F  1987-02-08
# 24       83335  1959-11-19             Fai      Klassen      F  1987-04-16
# 25       84604  1959-01-15             Fai         Luan      F  1997-06-19
# 26       85060  1955-08-17             Fai    Besselaar      F  1995-02-27
# 27       89204  1960-06-15             Fai    Huhdanpaa      F  1988-01-15
# 28       90480  1954-01-29             Fai       Mitina      F  1985-03-18
# 29       93249  1960-02-29             Fai       Radwan      F  1990-02-21
# ...        ...         ...             ...          ...    ...         ...
# 299994  423579  1954-05-09  Gopalakrishnan       Etalle      M  1986-01-11
# 299995  426125  1957-02-24  Gopalakrishnan         Luon      M  1986-01-11
# 299996  426270  1954-12-19  Gopalakrishnan      Sudkamp      M  1991-08-31
# 299997  429890  1963-09-19  Gopalakrishnan       Zaumen      M  1990-03-30
# 299998  430202  1955-07-25  Gopalakrishnan  Pusterhofer      M  1986-03-07
# 299999  432685  1955-02-08  Gopalakrishnan       Naudin      M  1990-08-04
# 300000  434701  1957-04-13  Gopalakrishnan     Ballarin      M  1985-07-22
# 300001  440049  1956-03-08  Gopalakrishnan       Sommen      M  1995-05-04
# 300002  440735  1956-12-28  Gopalakrishnan     Chachaty      M  1988-08-18
# 300003  445958  1958-03-13  Gopalakrishnan        Brlek      M  1991-10-06
# 300004  455984  1960-12-20  Gopalakrishnan        Cairo      M  1987-12-25
# 300005  458053  1962-09-22  Gopalakrishnan      Zuberek      M  1987-10-08
# 300006  459495  1954-09-29  Gopalakrishnan     Highland      M  1989-05-01
# 300007  466466  1956-03-12  Gopalakrishnan       Prenel      M  1987-12-05
# 300008  466987  1963-12-26  Gopalakrishnan      Mungall      M  1994-03-23
# 300009  467973  1955-04-10  Gopalakrishnan      Cannard      M  1987-05-23
# 300010  469925  1963-02-08  Gopalakrishnan       Morrow      M  1987-07-19
# 300011  469965  1961-08-16  Gopalakrishnan        Conia      M  1992-10-14
# 300012  470484  1962-03-08  Gopalakrishnan      Koblick      M  1987-04-28
# 300013  473203  1960-10-11  Gopalakrishnan       Irland      M  1994-02-07
# 300014  473804  1954-12-25  Gopalakrishnan         Baba      M  1986-12-15
# 300015  476278  1955-03-08  Gopalakrishnan    Panienski      M  1989-09-02
# 300016  483159  1964-06-29  Gopalakrishnan         Peng      M  1989-08-18
# 300017  485239  1963-09-08  Gopalakrishnan        Zizka      M  1990-06-23
# 300018  487517  1952-03-11  Gopalakrishnan      McClurg      M  1992-05-04
# 300019  489302  1955-12-08  Gopalakrishnan       Streng      M  1990-06-25
# 300020  491235  1961-12-11  Gopalakrishnan      Makinen      M  1992-03-25
# 300021  494936  1961-02-20  Gopalakrishnan       Uehara      M  1985-08-29
# 300022  496044  1958-05-26  Gopalakrishnan       Gornas      M  1988-10-27
# 300023  497144  1959-06-11  Gopalakrishnan        Setia      M  1990-08-16
#
#         salary
# 0        53448
# 1        46011
# 2        57978
# 3        42629
# 4        42539
# 5        42141
# 6        64246
# 7        60263
# 8        66303
# 9        90719
# 10       80372
# 11       49596
# 12       40000
# 13       60561
# 14       54582
# 15       40000
# 16       40000
# 17       70899
# 18       72250
# 19       61312
# 20       40000
# 21       54065
# 22       83421
# 23       51582
# 24       40345
# 25       40000
# 26       59452
# 27       58823
# 28       40000
# 29       40000
# ...        ...
# 299994   66609
# 299995   52581
# 299996   42028
# 299997   40015
# 299998   61519
# 299999   45080
# 300000   81414
# 300001   40000
# 300002   80185
# 300003   57849
# 300004   40000
# 300005   63598
# 300006   55181
# 300007   52030
# 300008   51004
# 300009   40000
# 300010   52192
# 300011   51276
# 300012   40514
# 300013   55105
# 300014   60638
# 300015   65491
# 300016   72801
# 300017   55135
# 300018   76116
# 300019   40000
# 300020   40000
# 300021   40000
# 300022   47626
# 300023   40000
#
# [300024 rows x 7 columns]

# %% [markdown]
# ※ 위와같이 테이블 여러개를 사용한다면 `as`를 사용해서 별칭을 정해준 후 사용할 수 있다

# %% [markdown]
# ### 8) GROUP BY
# - 그룹별로 집계함수 적용하기

# %% [markdown]
# - gender별 평균 salary를 구해라

# %%
# %%bigquery
# SELECT gender, avg(salary) as avg_salary_by_gender
# FROM (
#     SELECT emp.*, sal.salary
#     FROM `bigquery_test_db.employees` as emp
#     LEFT JOIN `bigquery_test_db.salaries` as sal
#         ON emp.emp_no = sal.emp_no
# )
# GROUP BY gender;
# Out:
#   gender  avg_salary_by_gender
# 0      F          52953.836428
# 1      M          52982.002945

# %% [markdown]
# ※ 위와 같이 FROM에 테이블명 대신 또 다른 SELECT 구문 사용할 수 있음

# %% [markdown]
# - gender별로 salary > 60000 인 유니크한 employee의 수를 구해라

# %%
# %%bigquery
# SELECT gender, COUNT(DISTINCT emp_no) as emp_cnt
# FROM (
#     SELECT emp.*, sal.salary
#     FROM `bigquery_test_db.employees` as emp
#     LEFT JOIN `bigquery_test_db.salaries` as sal
#         ON emp.emp_no = sal.emp_no
# )
# WHERE salary > 60000
# GROUP BY gender;
# Out:
#   gender  emp_cnt
# 0      F    33472
# 1      M    50163

# %% [markdown]
# ### 9) HAVING
# - GROUP BY로 그룹화 한 뒤에 조건을 걸어서 원하는 데이터 추출하는 명령어

# %% [markdown]
# - HAVING 사용 X : gender별로 유니크한 employee의 수를 구해라

# %%
# %%bigquery
# SELECT gender, COUNT(DISTINCT emp_no) as emp_cnt
# FROM (
#     SELECT emp.*, sal.salary
#     FROM `bigquery_test_db.employees` as emp
#     LEFT JOIN `bigquery_test_db.salaries` as sal
#         ON emp.emp_no = sal.emp_no
# )
# GROUP BY gender;
# Out:
#   gender  emp_cnt
# 0      F   120051
# 1      M   179973

# %% [markdown]
# - HAVING 사용 O : gender별로 유니크한 employee의 수를 구한 뒤 그 수가 150000 이상인 경우만 뽑아라

# %%
# %%bigquery
# SELECT gender, COUNT(DISTINCT emp_no) as emp_cnt
# FROM (
#     SELECT emp.*, sal.salary
#     FROM `bigquery_test_db.employees` as emp
#     LEFT JOIN `bigquery_test_db.salaries` as sal
#         ON emp.emp_no = sal.emp_no
# )
# GROUP BY gender
# HAVING emp_cnt >= 150000;
# Out:
#   gender  emp_cnt
# 0      M   179973
